# %%
print("Welcome to python Programming")
name=input("Enter your name")
age=input("Enter your age")
occ=input("Enter your occupation")
hobby=input("Enter your hobby")
print("Hello",name)
print("Your occupation is",occ,"at the age",age)
print("Your hobby is",hobby)
# Out:
# Welcome to python Programming
# Enter your nameveda
# Enter your age22
# Enter your occupationself employed
# Enter your hobbyhockey
# Hello veda
# Your occupation is self employed at the age 22
# Your hobby is hockey

# %%
print("Welcome Numeric Value program")
int_val=int(input("Enter integer value"))
float_val=float(input("Enter float value"))
complex_val=complex(input("Enter complex value"))
str=input("Enter string value")
smallfloat_val=float(input("Enter small float value"))
largefloat_val=float(input("Enter large float value"))
print("Integer value is",int_val)
print("Float value is",float_val)
print("Complex value is",complex_val)
print("String value is",str)
print("Small float value is",smallfloat_val)
print("Large float value is",largefloat_val)
# Out:
# Welcome Numeric Value program
# Enter integer value123
# Enter float value3.23
# Enter complex value4+8j
# Enter string valueved
# Enter small float value6.798
# Enter large float value45.865434567
# Integer value is 123
# Float value is 3.23
# Complex value is (4+8j)
# String value is ved
# Small float value is 6.798
# Large float value is 45.865434567

# %%
a=10
b=20
c=5
d=2
sum=a+b
sub=a-b
mul=a*b
div=a/b
mod=a%b
exp=a**b
print("Sum is",sum)
print("Sub is",sub)
print("Mul is",mul)
print("Div is",div)
print("Mod is",mod)
print("Exp is",exp)
result=((a+b)/c)*d+(c-d)
print("Result is",result)
# Out:
# Sum is 30
# Sub is -10
# Mul is 200
# Div is 0.5
# Mod is 10
# Exp is 100000000000000000000
# Result is 15.0
